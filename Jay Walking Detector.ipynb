# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib auto
# Out:
# Using matplotlib backend: Qt5Agg

# %% [markdown]
# ## load Image

# %%
image = cv2.imread('data/jaywalking.0.jpg')

# %%
plt.figure(figsize=(12,6))
plt.subplot(121)
plt.title('Jay Walker')
plt.axis('off')
plt.imshow(image[:,:,[2,1,0]])
plt.show()

# %% [markdown]
# ## Build Model

# %%
hog = cv2.HOGDescriptor()
hog.setSVMDetector(cv2.HOGDescriptor.getDefaultPeopleDetector())

# %%
locations, weights = hog.detectMultiScale(image)

# %%
dbg_image = image.copy()
for loc in locations:
    cv2.rectangle(dbg_image, (loc[0], loc[1]), 
                  (loc[0]+loc[2], loc[1]+loc[3]), (0, 255, 0), 2)

# %% [markdown]
# ## Visualize Output

# %%
plt.figure(figsize=(12,6))
plt.subplot(122)
plt.title('Jay Walker Caught')
plt.axis('off')
plt.imshow(dbg_image[:,:,[2,1,0]])
plt.tight_layout()
plt.show()
